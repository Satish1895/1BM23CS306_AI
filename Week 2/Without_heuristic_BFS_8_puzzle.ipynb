# %% [markdown]
# <a href="https://colab.research.google.com/github/Satish1895/1BM23CS306_AI/blob/main/BFS_8_puzzle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque

# Goal state for the 8 puzzle
# goal_state = '123804765'
# Using '0' as the empty space

# Moves: Up, Down, Left, Right
moves = {
    'Up': -3,
    'Down': 3,
    'Left': -1,
    'Right': 1
}

# Valid moves for each index to prevent wrapping around rows/columns
invalid_moves = {
    0: ['Up', 'Left'], 1: ['Up'], 2: ['Up', 'Right'],
    3: ['Left'],        5: ['Right'],
    6: ['Down', 'Left'], 7: ['Down'], 8: ['Down', 'Right']
}

# Function to generate new puzzle state after moving the blank
def move_tile(state, direction):
    index = state.index('0')
    if direction in invalid_moves.get(index, []):
        return None

    new_index = index + moves[direction]
    if new_index < 0 or new_index >= 9:
        return None

    state_list = list(state)
    # Swap 0 with the target tile
    state_list[index], state_list[new_index] = state_list[new_index], state_list[index]
    return ''.join(state_list)

# Helper function to print the state in 3x3 format
def print_state(state):
    for i in range(0, 9, 3):
        # Replace '0' with space for readability
        print(' '.join(state[i:i+3]).replace('0', ' '))
    print()  # Blank line for spacing

# BFS Algorithm with printing all visited states
def bfs(start_state, goal_state):
    visited = set()
    queue = deque([(start_state, [])])  # Each element is (state, path)
    visited_count = 0  # Initialize visited state counter

    while queue:
        current_state, path = queue.popleft()

        if current_state in visited:
            continue

        visited_count += 1 # Increment visited state counter

        # Print each visited state
        print("Visited state:")
        print_state(current_state)


        if current_state == goal_state:
            return path, visited_count # Return path and visited count

        visited.add(current_state)

        for direction in moves:
            new_state = move_tile(current_state, direction)
            if new_state and new_state not in visited:
                queue.append((new_state, path + [direction]))

    return None, visited_count # No solution found, return None and visited count

# Input initial state as a string (e.g., '123456780' where 0 is the blank)
start = input("Enter the INITIAL state (give '0'for empty space): ")
goal = input("Enter the GOAL state (give '0'for empty space): ")


if len(start) == 9 and set(start) == set('012345678') and len(goal) == 9 and set(goal) == set('012345678'):
    print("INITIAL state:")
    print_state(start)
    print("GOAL state:")
    print_state(goal)

    result, visited_count = bfs(start, goal) # Get both path and visited count

    if result is not None:
        print("Solution found!")
        print("Moves:", ' '.join(result))
        print("Number of moves:", len(result))
        current_state = start
        for i, move in enumerate(result, 1):
            current_state = move_tile(current_state, move)
            print(f"Move {i}: {move}")
            print_state(current_state)
    else:
        print("No solution exists for the given start state.")

    print("Number of visited states:", visited_count) # Print visited count

else:
    print("Invalid input! Please enter a 9-digit string using digits 0-8 without repetition.")
print("1BM23CS306 Satish G K\n")
# Out:
# Enter the INITIAL state (give '0'for empty space): 283164705
# Enter the GOAL state (give '0'for empty space): 123804765
# INITIAL state:
# 2 8 3
# 1 6 4
# 7   5
#
# GOAL state:
# 1 2 3
# 8   4
# 7 6 5
#
# Visited state:
# 2 8 3
# 1 6 4
# 7   5
#
# Visited state:
# 2 8 3
# 1   4
# 7 6 5
#
# Visited state:
# 2 8 3
# 1 6 4
#   7 5
#
# Visited state:
# 2 8 3
# 1 6 4
# 7 5
#
# Visited state:
# 2   3
# 1 8 4
# 7 6 5
#
# Visited state:
# 2 8 3
#   1 4
# 7 6 5
#
# Visited state:
# 2 8 3
# 1 4
# 7 6 5
#
# Visited state:
# 2 8 3
#   6 4
# 1 7 5
#
# Visited state:
# 2 8 3
# 1 6
# 7 5 4
#
# Visited state:
#   2 3
# 1 8 4
# 7 6 5
#
# Visited state:
# 2 3
# 1 8 4
# 7 6 5
#
# Visited state:
#   8 3
# 2 1 4
# 7 6 5
#
# Visited state:
# 2 8 3
# 7 1 4
#   6 5
#
# Visited state:
# 2 8
# 1 4 3
# 7 6 5
#
# Visited state:
# 2 8 3
# 1 4 5
# 7 6
#
# Visited state:
#   8 3
# 2 6 4
# 1 7 5
#
# Visited state:
# 2 8 3
# 6   4
# 1 7 5
#
# Visited state:
# 2 8
# 1 6 3
# 7 5 4
#
# Visited state:
# 2 8 3
# 1   6
# 7 5 4
#
# Visited state:
# 1 2 3
#   8 4
# 7 6 5
#
# Visited state:
# 2 3 4
# 1 8
# 7 6 5
#
# Visited state:
# 8   3
# 2 1 4
# 7 6 5
#
# Visited state:
# 2 8 3
# 7 1 4
# 6   5
#
# Visited state:
# 2   8
# 1 4 3
# 7 6 5
#
# Visited state:
# 2 8 3
# 1 4 5
# 7   6
#
# Visited state:
# 8   3
# 2 6 4
# 1 7 5
#
# Visited state:
# 2   3
# 6 8 4
# 1 7 5
#
# Visited state:
# 2 8 3
# 6 7 4
# 1   5
#
# Visited state:
# 2 8 3
# 6 4
# 1 7 5
#
# Visited state:
# 2   8
# 1 6 3
# 7 5 4
#
# Visited state:
# 2   3
# 1 8 6
# 7 5 4
#
# Visited state:
# 2 8 3
# 1 5 6
# 7   4
#
# Visited state:
# 2 8 3
#   1 6
# 7 5 4
#
# Visited state:
# 1 2 3
# 7 8 4
#   6 5
#
# Visited state:
# 1 2 3
# 8   4
# 7 6 5
#
# Solution found!
# Moves: Up Up Left Down Right
# Number of moves: 5
# Move 1: Up
# 2 8 3
# 1   4
# 7 6 5
#
# Move 2: Up
# 2   3
# 1 8 4
# 7 6 5
#
# Move 3: Left
#   2 3
# 1 8 4
# 7 6 5
#
# Move 4: Down
# 1 2 3
#   8 4
# 7 6 5
#
# Move 5: Right
# 1 2 3
# 8   4
# 7 6 5
#
# Number of visited states: 35
# 1BM23CS306 Satish G K
